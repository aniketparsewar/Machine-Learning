# %%
import graphlab

# %%
url = '/Users/Aniket/anaconda/infy.csv'
infy = graphlab.SFrame.read_csv(url)
infy['Date'] = infy['Date'].str_to_datetime('%d/%m/%y')
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to aniketparsewar@yahoo.co.in and will expire on October 15, 2017.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1479703911.log
# Finished parsing file /Users/Aniket/anaconda/infy.csv
# Parsing completed. Parsed 100 lines in 0.038512 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,int,float,float,float,float,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Unable to parse line "1325,09/08/11,2011221,-,-,-,13.79,0,6905"
# Unable to parse line "1337,22/07/11,2011203,-,-,-,15.92,0,6905"
# Unable to parse line "1343,14/07/11,2011195,-,-,-,15.26,0,6905"
# Unable to parse line "1351,01/07/11,2011182,-,-,-,16.52,0,6905"
# Unable to parse line "1352,30/06/11,2011181,-,-,-,16.31,0,6668"
# Unable to parse line "1355,27/06/11,2011178,-,-,-,15.9,0,6668"
# Unable to parse line "1357,23/06/11,2011174,-,-,-,15.53,0,6668"
# Unable to parse line "1375,27/05/11,2011147,-,-,-,15.41,0,6668"
# Unable to parse line "1381,19/05/11,2011139,-,-,-,15.66,0,6668"
# Unable to parse line "1384,16/05/11,2011136,-,-,-,15.9,0,6668"
# 44 lines failed to parse correctly
# Finished parsing file /Users/Aniket/anaconda/infy.csv
# Parsing completed. Parsed 3954 lines in 0.028145 secs.

# %%
infy.head()
# Out:
# Columns:
# 	id	int
# 	Date	datetime
# 	Jdate	int
# 	Open	float
# 	High	float
# 	Low	float
# 	Close	float
# 	Volume	int
# 	Revenue	int
#
# Rows: 10
#
# Data:
# +----+---------------------+---------+-------+-------+-------+-------+----------+
# | id |         Date        |  Jdate  |  Open |  High |  Low  | Close |  Volume  |
# +----+---------------------+---------+-------+-------+-------+-------+----------+
# | 1  | 2016-11-11 00:00:00 | 2016316 | 14.23 | 14.54 | 14.19 | 14.51 | 7884523  |
# | 2  | 2016-11-10 00:00:00 | 2016315 | 14.49 | 14.52 | 14.29 | 14.44 | 9682656  |
# | 3  | 2016-11-09 00:00:00 | 2016314 | 14.92 | 14.92 | 14.27 | 14.54 | 17091179 |
# | 4  | 2016-11-08 00:00:00 | 2016313 | 15.22 | 15.26 |  15.1 | 15.16 | 4298362  |
# | 5  | 2016-11-04 00:00:00 | 2016309 | 14.96 | 15.16 | 14.92 | 15.04 | 5594060  |
# | 6  | 2016-11-03 00:00:00 | 2016308 | 15.04 | 15.07 | 14.93 | 14.96 | 3705972  |
# | 7  | 2016-11-02 00:00:00 | 2016307 | 15.19 | 15.22 | 15.02 | 15.16 | 2342391  |
# | 8  | 2016-11-01 00:00:00 | 2016306 | 15.19 | 15.29 | 15.14 | 15.26 | 3572573  |
# | 9  | 2016-10-31 00:00:00 | 2016305 | 15.31 | 15.38 | 15.19 | 15.26 | 4157977  |
# | 10 | 2016-10-28 00:00:00 | 2016302 | 15.37 | 15.48 | 15.24 | 15.29 | 5001281  |
# +----+---------------------+---------+-------+-------+-------+-------+----------+
# +---------+
# | Revenue |
# +---------+
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# +---------+
# [10 rows x 9 columns]

# %%
graphlab.set_runtime_config('GRAPHLAB_DEFAULT_NUM_PYLAMBDA_WORKERS', 4)

# %%
graphlab.canvas.set_target('ipynb')
infy.show(view="Line Chart", x="Date", y="Close")

# %%
infy.show()

# %%
graphlab.canvas.set_target('ipynb')
infy.show(view="Scatter Plot", x="Revenue", y="Close")
train_data,test_data = infy.random_split(0.8,seed=0)

# %%
train_data
# Out:
# Columns:
# 	id	int
# 	Date	datetime
# 	Jdate	int
# 	Open	float
# 	High	float
# 	Low	float
# 	Close	float
# 	Volume	int
# 	Revenue	int
#
# Rows: Unknown
#
# Data:
# +----+---------------------+---------+-------+-------+-------+-------+----------+
# | id |         Date        |  Jdate  |  Open |  High |  Low  | Close |  Volume  |
# +----+---------------------+---------+-------+-------+-------+-------+----------+
# | 1  | 2016-11-11 00:00:00 | 2016316 | 14.23 | 14.54 | 14.19 | 14.51 | 7884523  |
# | 2  | 2016-11-10 00:00:00 | 2016315 | 14.49 | 14.52 | 14.29 | 14.44 | 9682656  |
# | 3  | 2016-11-09 00:00:00 | 2016314 | 14.92 | 14.92 | 14.27 | 14.54 | 17091179 |
# | 4  | 2016-11-08 00:00:00 | 2016313 | 15.22 | 15.26 |  15.1 | 15.16 | 4298362  |
# | 5  | 2016-11-04 00:00:00 | 2016309 | 14.96 | 15.16 | 14.92 | 15.04 | 5594060  |
# | 6  | 2016-11-03 00:00:00 | 2016308 | 15.04 | 15.07 | 14.93 | 14.96 | 3705972  |
# | 7  | 2016-11-02 00:00:00 | 2016307 | 15.19 | 15.22 | 15.02 | 15.16 | 2342391  |
# | 8  | 2016-11-01 00:00:00 | 2016306 | 15.19 | 15.29 | 15.14 | 15.26 | 3572573  |
# | 9  | 2016-10-31 00:00:00 | 2016305 | 15.31 | 15.38 | 15.19 | 15.26 | 4157977  |
# | 10 | 2016-10-28 00:00:00 | 2016302 | 15.37 | 15.48 | 15.24 | 15.29 | 5001281  |
# +----+---------------------+---------+-------+-------+-------+-------+----------+
# +---------+
# | Revenue |
# +---------+
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# |  15000  |
# +---------+
# [? rows x 9 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
infy_model = graphlab.linear_regression.create(train_data, target='Close', features=['Revenue'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 2996
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | 1         | 2        | 1.003760     | 8.966017           | 8.926017             | 3.260814      | 3.458705        |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
print test_data['Close'].mean()
# Out:
# 9.53352718078

# %%
print infy_model.evaluate(test_data)
# Out:
# {'max_error': 8.460357780197313, 'rmse': 3.2272488958368846}

# %%
infy_model.get('coefficients')
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 2
#
# Data:
# +-------------+-------+------------------+-------------------+
# |     name    | index |      value       |       stderr      |
# +-------------+-------+------------------+-------------------+
# | (intercept) |  None |  2.96038151144   |   0.097379442959  |
# |   Revenue   |  None | 0.00114074096628 | 1.37248636036e-05 |
# +-------------+-------+------------------+-------------------+
# [2 rows x 4 columns]

# %%
price = infy[infy['id']== 454]

# %%
price
# Out:
# Columns:
# 	id	int
# 	Date	datetime
# 	Jdate	int
# 	Open	float
# 	High	float
# 	Low	float
# 	Close	float
# 	Volume	int
# 	Revenue	int
#
# Rows: Unknown
#
# Data:
# +-----+---------------------+---------+-------+------+-------+-------+---------+
# |  id |         Date        |  Jdate  |  Open | High |  Low  | Close |  Volume |
# +-----+---------------------+---------+-------+------+-------+-------+---------+
# | 454 | 2015-01-27 00:00:00 | 2015027 | 17.42 | 17.7 | 17.38 | 17.57 | 6615428 |
# +-----+---------------------+---------+-------+------+-------+-------+---------+
# +---------+
# | Revenue |
# +---------+
# |  12192  |
# +---------+
# [? rows x 9 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
print infy_model.predict(price)
# Out:
# [16.868295372349223]

# %%
my_features = ['Revenue', 'Jdate']

# %%
infy[my_features].show()

# %%
infy.show(view='BoxWhisker Plot', x='Revenue', y='Close')

# %%
infy_features_model = graphlab.linear_regression.create(train_data,target='Close',features=my_features,validation_set=None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 3163
# Number of features          : 2
# Number of unpacked features : 2
# Number of coefficients    : 3
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# +-----------+----------+--------------+--------------------+---------------+
# | 1         | 2        | 0.004942     | 8.703935           | 3.165860      |
# +-----------+----------+--------------+--------------------+---------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
print infy_model.evaluate(test_data)
print infy_features_model.evaluate(test_data)
# Out:
# {'max_error': 8.460357780197313, 'rmse': 3.2272488958368846}
# {'max_error': 8.282913425457423, 'rmse': 3.118597495456952}

# %%
print infy_model.predict(price)
# Out:
# [16.868295372349223]

# %%
print infy_features_model.predict(price)
# Out:
# [16.846025323031824]

# %%
price
# Out:
# Columns:
# 	id	int
# 	Date	datetime
# 	Jdate	int
# 	Open	float
# 	High	float
# 	Low	float
# 	Close	float
# 	Volume	int
# 	Revenue	int
#
# Rows: 1
#
# Data:
# +-----+---------------------+---------+-------+------+-------+-------+---------+
# |  id |         Date        |  Jdate  |  Open | High |  Low  | Close |  Volume |
# +-----+---------------------+---------+-------+------+-------+-------+---------+
# | 454 | 2015-01-27 00:00:00 | 2015027 | 17.42 | 17.7 | 17.38 | 17.57 | 6615428 |
# +-----+---------------------+---------+-------+------+-------+-------+---------+
# +---------+
# | Revenue |
# +---------+
# |  12192  |
# +---------+
# [1 rows x 9 columns]

# %%
knn_infy_model = graphlab.nearest_neighbors.create(train_data,
                                             features = ['Revenue'],
                                             label = 'id')
# Out:
# Starting ball tree nearest neighbors model training.
# +------------+--------------+
# | Tree level | Elapsed Time |
# +------------+--------------+
# | 0          | 686us        |
# | 1          | 1.379ms      |
# | 2          | 1.691ms      |
# +------------+--------------+

# %%
knn_infy_model.query(price)
# Out:
# +--------------+-------------+--------------+
# | Query points | % Complete. | Elapsed Time |
# +--------------+-------------+--------------+
# | 1            | 100         | 1.396ms      |
# | Done         |             | 1.532ms      |
# +--------------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+----------+------+
# | query_label | reference_label | distance | rank |
# +-------------+-----------------+----------+------+
# |      0      |       470       |   0.0    |  1   |
# |      0      |       467       |   0.0    |  2   |
# |      0      |       466       |   0.0    |  3   |
# |      0      |       465       |   0.0    |  4   |
# |      0      |       464       |   0.0    |  5   |
# +-------------+-----------------+----------+------+
# [5 rows x 4 columns]

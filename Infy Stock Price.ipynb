# %%
import graphlab

# %%
url = '/Users/Aniket/anaconda/infy.csv'
infy = graphlab.SFrame.read_csv(url)
infy['Date'] = infy['Date'].str_to_datetime('%d/%m/%y')
# Out:
# Finished parsing file /Users/Aniket/anaconda/infy.csv
# Parsing completed. Parsed 100 lines in 0.036701 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,float,float,float,float,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Unable to parse line "1325,09/08/11,-,-,-,13.79,0,6905"
# Unable to parse line "1337,22/07/11,-,-,-,15.92,0,6905"
# Unable to parse line "1343,14/07/11,-,-,-,15.26,0,6905"
# Unable to parse line "1351,01/07/11,-,-,-,16.52,0,6905"
# Unable to parse line "1352,30/06/11,-,-,-,16.31,0,6668"
# Unable to parse line "1355,27/06/11,-,-,-,15.9,0,6668"
# Unable to parse line "1357,23/06/11,-,-,-,15.53,0,6668"
# Unable to parse line "1375,27/05/11,-,-,-,15.41,0,6668"
# Unable to parse line "1381,19/05/11,-,-,-,15.66,0,6668"
# Unable to parse line "1384,16/05/11,-,-,-,15.9,0,6668"
# 44 lines failed to parse correctly
# Finished parsing file /Users/Aniket/anaconda/infy.csv
# Parsing completed. Parsed 3954 lines in 0.021308 secs.

# %%
infy.head()
# Out:
# Columns:
# 	id	int
# 	Date	datetime
# 	Open	float
# 	High	float
# 	Low	float
# 	Close	float
# 	Volume	int
# 	Revenue	int
#
# Rows: 10
#
# Data:
# +----+---------------------+-------+-------+-------+-------+----------+---------+
# | id |         Date        |  Open |  High |  Low  | Close |  Volume  | Revenue |
# +----+---------------------+-------+-------+-------+-------+----------+---------+
# | 1  | 2016-11-11 00:00:00 | 14.23 | 14.54 | 14.19 | 14.51 | 7884523  |  15000  |
# | 2  | 2016-11-10 00:00:00 | 14.49 | 14.52 | 14.29 | 14.44 | 9682656  |  15000  |
# | 3  | 2016-11-09 00:00:00 | 14.92 | 14.92 | 14.27 | 14.54 | 17091179 |  15000  |
# | 4  | 2016-11-08 00:00:00 | 15.22 | 15.26 |  15.1 | 15.16 | 4298362  |  15000  |
# | 5  | 2016-11-04 00:00:00 | 14.96 | 15.16 | 14.92 | 15.04 | 5594060  |  15000  |
# | 6  | 2016-11-03 00:00:00 | 15.04 | 15.07 | 14.93 | 14.96 | 3705972  |  15000  |
# | 7  | 2016-11-02 00:00:00 | 15.19 | 15.22 | 15.02 | 15.16 | 2342391  |  15000  |
# | 8  | 2016-11-01 00:00:00 | 15.19 | 15.29 | 15.14 | 15.26 | 3572573  |  15000  |
# | 9  | 2016-10-31 00:00:00 | 15.31 | 15.38 | 15.19 | 15.26 | 4157977  |  15000  |
# | 10 | 2016-10-28 00:00:00 | 15.37 | 15.48 | 15.24 | 15.29 | 5001281  |  15000  |
# +----+---------------------+-------+-------+-------+-------+----------+---------+
# [10 rows x 8 columns]

# %%
graphlab.set_runtime_config('GRAPHLAB_DEFAULT_NUM_PYLAMBDA_WORKERS', 4)

# %%
graphlab.canvas.set_target('ipynb')
infy.show(view="Line Chart", x="Date", y="Close")

# %%
infy.show()

# %%
graphlab.canvas.set_target('ipynb')
infy.show(view="Scatter Plot", x="Revenue", y="Close")
train_data,test_data = infy.random_split(0.8,seed=0)

# %%
train_data
# Out:
# Columns:
# 	id	int
# 	Date	datetime
# 	Open	float
# 	High	float
# 	Low	float
# 	Close	float
# 	Volume	int
# 	Revenue	int
#
# Rows: Unknown
#
# Data:
# +----+---------------------+-------+-------+-------+-------+----------+---------+
# | id |         Date        |  Open |  High |  Low  | Close |  Volume  | Revenue |
# +----+---------------------+-------+-------+-------+-------+----------+---------+
# | 1  | 2016-11-11 00:00:00 | 14.23 | 14.54 | 14.19 | 14.51 | 7884523  |  15000  |
# | 2  | 2016-11-10 00:00:00 | 14.49 | 14.52 | 14.29 | 14.44 | 9682656  |  15000  |
# | 3  | 2016-11-09 00:00:00 | 14.92 | 14.92 | 14.27 | 14.54 | 17091179 |  15000  |
# | 4  | 2016-11-08 00:00:00 | 15.22 | 15.26 |  15.1 | 15.16 | 4298362  |  15000  |
# | 5  | 2016-11-04 00:00:00 | 14.96 | 15.16 | 14.92 | 15.04 | 5594060  |  15000  |
# | 6  | 2016-11-03 00:00:00 | 15.04 | 15.07 | 14.93 | 14.96 | 3705972  |  15000  |
# | 7  | 2016-11-02 00:00:00 | 15.19 | 15.22 | 15.02 | 15.16 | 2342391  |  15000  |
# | 8  | 2016-11-01 00:00:00 | 15.19 | 15.29 | 15.14 | 15.26 | 3572573  |  15000  |
# | 9  | 2016-10-31 00:00:00 | 15.31 | 15.38 | 15.19 | 15.26 | 4157977  |  15000  |
# | 10 | 2016-10-28 00:00:00 | 15.37 | 15.48 | 15.24 | 15.29 | 5001281  |  15000  |
# +----+---------------------+-------+-------+-------+-------+----------+---------+
# [? rows x 8 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
infy_model = graphlab.linear_regression.create(train_data, target='Close', features=['Revenue'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 3008
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | 1         | 2        | 0.012222     | 8.956783           | 8.251046             | 3.263115      | 3.430421        |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
print test_data['Close'].mean()
# Out:
# 9.53352718078

# %%
print infy_model.evaluate(test_data)
# Out:
# {'max_error': 8.451045669754642, 'rmse': 3.227084881391102}

# %%
infy_model.get('coefficients')
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 2
#
# Data:
# +-------------+-------+------------------+-------------------+
# |     name    | index |      value       |       stderr      |
# +-------------+-------+------------------+-------------------+
# | (intercept) |  None |  2.97432360547   |  0.0973711933992  |
# |   Revenue   |  None | 0.00114002034627 | 1.36734999223e-05 |
# +-------------+-------+------------------+-------------------+
# [2 rows x 4 columns]

# %%
price = infy[infy['id']== 454]

# %%
price
# Out:
# Columns:
# 	id	int
# 	Date	datetime
# 	Open	float
# 	High	float
# 	Low	float
# 	Close	float
# 	Volume	int
# 	Revenue	int
#
# Rows: Unknown
#
# Data:
# +-----+---------------------+-------+------+-------+-------+---------+---------+
# |  id |         Date        |  Open | High |  Low  | Close |  Volume | Revenue |
# +-----+---------------------+-------+------+-------+-------+---------+---------+
# | 454 | 2015-01-27 00:00:00 | 17.42 | 17.7 | 17.38 | 17.57 | 6615428 |  12192  |
# +-----+---------------------+-------+------+-------+-------+---------+---------+
# [? rows x 8 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
print infy_model.predict(price)
# Out:
# [16.873451667176347]

# %%
my_features = ['Revenue', 'Volume']

# %%
infy[my_features].show()

# %%
infy.show(view='BoxWhisker Plot', x='Revenue', y='Close')

# %%
infy_features_model = graphlab.linear_regression.create(train_data,target='Close',features=my_features,validation_set=None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 3163
# Number of features          : 2
# Number of unpacked features : 2
# Number of coefficients    : 3
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# +-----------+----------+--------------+--------------------+---------------+
# | 1         | 2        | 0.005072     | 8.625080           | 3.241523      |
# +-----------+----------+--------------+--------------------+---------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
print infy_model.evaluate(test_data)
print infy_features_model.evaluate(test_data)
# Out:
# {'max_error': 8.451045669754642, 'rmse': 3.227084881391102}
# {'max_error': 10.22728778625658, 'rmse': 3.2281205353984777}

# %%
print infy_model.predict(price)
# Out:
# [16.873451667176347]

# %%
print infy_features_model.predict(price)
# Out:
# [16.833117295129462]

# %%
price
# Out:
# Columns:
# 	id	int
# 	Date	datetime
# 	Open	float
# 	High	float
# 	Low	float
# 	Close	float
# 	Volume	int
# 	Revenue	int
#
# Rows: 1
#
# Data:
# +-----+---------------------+-------+------+-------+-------+---------+---------+
# |  id |         Date        |  Open | High |  Low  | Close |  Volume | Revenue |
# +-----+---------------------+-------+------+-------+-------+---------+---------+
# | 454 | 2015-01-27 00:00:00 | 17.42 | 17.7 | 17.38 | 17.57 | 6615428 |  12192  |
# +-----+---------------------+-------+------+-------+-------+---------+---------+
# [1 rows x 8 columns]
